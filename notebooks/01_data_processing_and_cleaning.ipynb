# %%
# Environment Setup

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Environment check: All required libraries are imported successfully.")

# %%
df = pd.read_csv('../data/raw/heart_disease_health_indicators_BRFSS2015.csv')

df.shape
df.info()
df.head()
df.columns

df['HeartDiseaseorAttack'].value_counts() # Check ratio of people with heart disease/attack vs not
df['HeartDiseaseorAttack'].value_counts(normalize=True)

# %%
# Missing values and duplicates

print(df.isnull().sum()) 
print(df.duplicated().sum())

df = df.drop_duplicates() # Drop duplicates if any
df.shape

# %%
# Value range sanity check

df.describe()

df['BMI'].describe()
df[df['BMI'] > 60]

# %%
# Save the cleaned dataset to a new CSV file
df.to_csv('../data/processed/heart_disease_cleaned.csv', index=False)
